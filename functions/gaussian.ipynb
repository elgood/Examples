# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

x = np.arange(-10, 10, 0.001) # the x-axis
y = np.zeros(len(x))
for i in range(len(x)):
  y[i] = math.exp(-pow(x[i],2))

plt.plot(x, y)
